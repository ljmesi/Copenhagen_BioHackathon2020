# %% [markdown]
# # Filter data based on keywords

# %% [markdown]
# ## Introduction
# The aim of this notebook is to read a set of keywords and a set of scraped data and filter out all non-Covid-19 related entries/rows.

# %% [markdown]
# ## Import libraries and set up defaults

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline
#%xmode Verbose
# Set global default figure size
plt.rc('figure', figsize=(20, 12)) # It's nice with figures that fill the whole space in width
# Show maximum of 8 rows when printing dataframes
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 8
# Show only 4 digits when printing floating point number
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Read in the keywords

# %%
raw = "01_raw/"
key_words_df = pd.read_csv(raw + "filtering_terms.tsv",
                           sep = '\t',
                           header = 0,
                           usecols = ['ORF','Gene','Gene2','Full_Name','Disease_Names'] # Dropping Search_Terms column
                          )
key_words_df
# Out:
#        ORF  Gene Gene2                             Full_Name Disease_Names
# 0   ORF1AB  nsp1   NaN       Host translation inhibitor nsp1    sars-cov-2
# 1   ORF1AB  nsp2   NaN              Non-structural protein 2     sars-cov2
# 2   ORF1AB  nps3   NaN                Papain-like proteinase       covid19
# 3   ORF1AB  nps4   NaN              Non-structural protein 4      covid-19
# ..     ...   ...   ...                                   ...           ...
# 24     NaN   NaN   NaN                             S-protein           NaN
# 25     NaN   NaN   NaN                         Spike protein           NaN
# 26     NaN   NaN   NaN       Spike trimeric complex (S1S2S`)           NaN
# 27     NaN   NaN   NaN  Spike surface glycoprotein (monomer)           NaN
#
# [28 rows x 5 columns]

# %% [markdown]
# Most of the key words above are from [Zhang Lab's](https://zhanglab.ccmb.med.umich.edu/COVID-19/) website.

# %% [markdown]
# #### Create a unique Python list of keywords

# %%
first_term = (key_words_df['ORF']
              .dropna() # Drop np.nan:s
              .unique() # Filter all non-unique values
              .tolist() # Make a python list
             ) + \
key_words_df['Gene'].dropna().unique().tolist() + \
key_words_df['Gene2'].dropna().unique().tolist() + \
key_words_df['Full_Name'].dropna().unique().tolist() + \
key_words_df['Disease_Names'].dropna().unique().tolist()
print(first_term)
# Out:
# ['ORF1AB', 'S', 'ORF3A', 'E', 'M', 'ORF6', 'ORF7A', 'ORF8', 'N', 'ORF10', 'nsp1', 'nsp2', 'nps3', 'nps4', 'nsp5', 'nsp6', 'nsp7', 'nsp8', 'nsp9', 'nsp10', 'RDRP', 'Hel', 'Exon', 'NendoU', "2'-O-MT", 'Spike', '3CL-PRO', 'Spike trimeric complex (S1, S2, S`)', 'Host translation inhibitor nsp1', 'Non-structural protein 2', 'Papain-like proteinase', 'Non-structural protein 4', '3C-like proteinase', 'Non-structural protein 6', 'Non-structural protein 7', 'Non-structural protein 8', 'Non-structural protein 9', 'Non-structural protein 10', 'RNA-Directed RNA Polymerase', 'Helicase', 'Proofreading exoribonuclease (Guanine-N7 methyltransferase)', 'Uridylate-specific endoribonuclease', "2'-O-methyltransferase", 'Spike surface glycoprotein (monomer)', 'Protein 3a', 'Envelope small membrane proteins', 'Membrane protein', 'Protein 6', 'Protein 7a', 'Protein 8', 'Nucleoprotein', '3` UTR', 'S-protein', 'Spike protein', 'Spike trimeric complex (S1S2S`)', 'sars-cov-2', 'sars-cov2', 'covid19', 'covid-19', 'sars', 'coronavirus', 'ncov2019', 'ncov-2019', 'nCov2019', 'nCov-2019', 'COVID2019', 'nCoV']

# %% [markdown]
# Let's remove some blatantly non-specific search terms such as "S" or "E":

# %%
excludable_terms = ['S',
                    'E', 
                    'M', 
                    'N', 
                    'Hel', 
                    'Exon', 
                    'Helicase', 
                    '3` UTR'
                   ]
first_term = [term for term in first_term if
          all(excludable not in term for excludable in excludable_terms)]

# %% [markdown]
# Let's make all the keywords lower case for easier use.

# %%
first_term = [term.lower() for term in first_term]
first_term
# Out:
# ['orf1ab',
#  'orf3a',
#  'orf6',
#  'orf7a',
#  'orf8',
#  'orf10',
#  'nsp1',
#  'nsp2',
#  'nps3',
#  'nps4',
#  'nsp5',
#  'nsp6',
#  'nsp7',
#  'nsp8',
#  'nsp9',
#  'nsp10',
#  'rdrp',
#  '3cl-pro',
#  'host translation inhibitor nsp1',
#  'papain-like proteinase',
#  '3c-like proteinase',
#  'uridylate-specific endoribonuclease',
#  "2'-o-methyltransferase",
#  'protein 3a',
#  'protein 6',
#  'protein 7a',
#  'protein 8',
#  'sars-cov-2',
#  'sars-cov2',
#  'covid19',
#  'covid-19',
#  'sars',
#  'coronavirus',
#  'ncov2019',
#  'ncov-2019',
#  'ncov2019',
#  'ncov-2019',
#  'covid2019',
#  'ncov']

# %% [markdown]
# ## Read in Scraped data from Mendeley Database

# %%
md_data = pd.read_csv(raw + "mendeley_molecular_dynamics.csv",
                   sep = ",",
                   header = 0
                  )
md_data.head()
# Out:
#                                   accessRights  \
# 0                                          NaN
# 1  http://www.gnu.org/licenses/gpl-3.0.en.html
# 2      info:eu-repo/semantics/restrictedAccess
# 3                                          NaN
# 4            info:eu-repo/semantics/openAccess
#
#                                              authors  \
# 0  NMR structure and <strong>molecular</strong> <...
# 1  Sergio Davis|Claudia Loyola|Felipe González|Jo...
# 2                                     Walter Rocchia
# 3                Laranjeiro, Ricardo|Whitmore, David
# 4                          Henrik Andersen Sveinsson
#
#                                         containerURI             dataTypes  \
# 0  http://www.bmrb.wisc.edu/data_library/summary/...          DATASET|TEXT
# 1      https://data.mendeley.com/datasets/v55y7vcyrx      DATASET|FILE_SET
# 2                  https://zenodo.org/record/2649259         OTHER|DATASET
# 3                https://doi.org/10.5061/dryad.r07bc  TABULAR_DATA|DATASET
# 4                  https://zenodo.org/record/3769670               DATASET
#
#   dateAvailable                                        description  \
# 0           NaN  Natural source:\nCommon Name:.  Taxonomy ID:. ...
# 1    2019-03-14  This program has been imported from the CPC Pr...
# 2    2019-11-01  This dataset contains Molecular Dynamics traje...
# 3    2014-06-13  The circadian clock is known to regulate a wid...
# 4    2020-04-29  Atom coordinates for molecular dynamics. For u...
#
#                       doi                               externalSubjectAreas  \
# 0        10.13018/BMR6757                                                NaN
# 1   10.17632/v55y7vcyrx.1  Surface Science|Condensed Matter Physics|Compu...
# 2  10.5281/zenodo.2649259                                 molecular dynamics
# 3     10.5061/dryad.r07bc  photoreceptors|neuroD|retina|transcription fac...
# 4  10.5281/zenodo.3769670                                                NaN
#
#                                         institutions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Centre for Cell and Molecular Dynamics, Depart...
# 4                                                NaN
#
#                                             keywords method publicationDate  \
# 0                                                NaN    NaN             NaN
# 1  Surface Science|Condensed Matter Physics|Compu...    NaN      2019-03-14
# 2                                 molecular dynamics    NaN      2019-04-30
# 3                                        Danio rerio    NaN      2014-06-13
# 4                                                NaN    NaN      2020-04-27
#
#                                    source  \
# 0  BIOLOGICAL_MAGNETIC_RESONANCE_DATABANK
# 1                           MENDELEY_DATA
# 2                                  ZENODO
# 3                                   DRYAD
# 4                                  ZENODO
#
#                                                title type_cont  version
# 0                                                  1   article      NaN
# 1  Las Palmeras Molecular Dynamics: A flexible an...   article      1.0
# 2              Molecular dynamics simulation dataset   article      NaN
# 3  Data from: Transcription factors involved in r...       NaN      NaN
# 4            Atom coordinates for molecular dynamics   article      NaN

# %%
mt_data = pd.read_csv(raw + "mendeley_molecular_trajectories.csv",
                   sep = ",",
                   header = 0
                  )
mt_data.head()
# Out:
#                                         accessRights  \
# 0                                                NaN
# 1                  info:eu-repo/semantics/openAccess
# 2            info:eu-repo/semantics/restrictedAccess
# 3                                          CC BY 4.0
# 4  https://www.elsevier.com/about/policies/open-a...
#
#                                              authors  \
# 0  Trujillo, Kevin|Papagiannopoulos, Tasso|Olsen,...
# 1                            Jiří Průša|Michal Cifra
# 2                                     Walter Rocchia
# 3        Kenney, Ian M.|Shujie Fan|Beckstein, Oliver
# 4        Ioannis G. Tsoulos|Athanassios Stavrakoudis
#
#                                         containerURI         dataTypes  \
# 0  https://doi.org/10.5256%2Ff1000research.6127.d...           DATASET
# 1                  https://zenodo.org/record/3676936           DATASET
# 2                  https://zenodo.org/record/2649259     OTHER|DATASET
# 3      https://doi.org/10.6084%2Fm9.figshare.7185203           DATASET
# 4      https://data.mendeley.com/datasets/55rdy6fdyc  DATASET|FILE_SET
#
#   dateAvailable                                        description  \
# 0           NaN  The data are represented as trajectory files (...
# 1    2020-02-21  Molecular dynamics (MD) trajectories of water ...
# 2    2019-11-01  This dataset contains Molecular Dynamics traje...
# 3           NaN  Molecular dynamics (MD) trajectory of the NhaA...
# 4    2019-12-05  Abstract \n Eucb is a standalone program for g...
#
#                                  doi  \
# 0  10.5256/f1000research.6127.d43528
# 1             10.5281/zenodo.3676936
# 2             10.5281/zenodo.2649259
# 3        10.6084/m9.figshare.7185203
# 4              10.17632/55rdy6fdyc.1
#
#                                 externalSubjectAreas institutions  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                 molecular dynamics          NaN
# 3  60112 Structural Biology (incl. Macromolecular...          NaN
# 4  Biological Sciences|Computational Physics|Mole...          NaN
#
#                                             keywords method publicationDate  \
# 0                                                NaN    NaN      2015-01-01
# 1                                                NaN    NaN      2020-02-20
# 2                                 molecular dynamics    NaN      2019-04-30
# 3                                                NaN    NaN      2018-01-01
# 4  Biological Sciences|Computational Physics|Mole...    NaN      2019-12-05
#
#           source                                              title type_cont  \
# 0      bl.f1000r            Data of molecular dynamics trajectories       NaN
# 1         ZENODO         A1904 molecular dynamics trajectories data   article
# 2         ZENODO              Molecular dynamics simulation dataset   article
# 3   figshare.ars  Molecular dynamics trajectory of membrane prot...       NaN
# 4  MENDELEY_DATA  Eucb: A C++ program for molecular dynamics tra...   article
#
#    version
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      1.0

# %% [markdown]
# ## Check that the data is OK

# %%
md_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2002 entries, 0 to 2001
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accessRights          1546 non-null   object
#  1   authors               2001 non-null   object
#  2   containerURI          2002 non-null   object
#  3   dataTypes             2002 non-null   object
#  4   dateAvailable         1245 non-null   object
#  5   description           2002 non-null   object
#  6   doi                   2002 non-null   object
#  7   externalSubjectAreas  1786 non-null   object
#  8   institutions          308 non-null    object
#  9   keywords              967 non-null    object
#  10  method                86 non-null     object
#  11  publicationDate       2000 non-null   object
#  12  source                2002 non-null   object
#  13  title                 2002 non-null   object
#  14  type_cont             982 non-null    object
#  15  version               626 non-null    float64
# dtypes: float64(1), object(15)
# memory usage: 250.4+ KB

# %%
mt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accessRights          346 non-null    object
#  1   authors               438 non-null    object
#  2   containerURI          438 non-null    object
#  3   dataTypes             438 non-null    object
#  4   dateAvailable         373 non-null    object
#  5   description           438 non-null    object
#  6   doi                   438 non-null    object
#  7   externalSubjectAreas  379 non-null    object
#  8   institutions          86 non-null     object
#  9   keywords              291 non-null    object
#  10  method                13 non-null     object
#  11  publicationDate       438 non-null    object
#  12  source                438 non-null    object
#  13  title                 438 non-null    object
#  14  type_cont             291 non-null    object
#  15  version               130 non-null    float64
# dtypes: float64(1), object(15)
# memory usage: 54.9+ KB

# %% [markdown]
# There are 2 columns with almost all `np.nan`:s in both data sets, namely 'method' and 'institutions'. Let's check out what they contain just for curiosity's sake. (This doesn't really affect anything else in the ensuing analyses.)

# %%
md_data.loc[md_data["method"].notnull()] # https://stackoverflow.com/a/42137824
# Out:
#                                         accessRights  \
# 36        http://creativecommons.org/licenses/by/4.0
# 38        http://creativecommons.org/licenses/by/4.0
# 107   https://creativecommons.org/licenses/by-nc/3.0
# 128       http://creativecommons.org/licenses/by/4.0
# ...                                              ...
# 1982      http://creativecommons.org/licenses/by/4.0
# 1994      http://creativecommons.org/licenses/by/4.0
# 1997      http://creativecommons.org/licenses/by/4.0
# 1999      http://creativecommons.org/licenses/by/4.0
#
#                                                 authors  \
# 36         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# 38         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# 107                                         Liao Y Chen
# 128                                      Ivan Novoselov
# ...                                                 ...
# 1982  Taro  Mieno|Aaron Hrozencik|Jordan Suter|Mani ...
# 1994                            Francesco Paolo Mancuso
# 1997                                            Jibo He
# 1999  Connon I. Thomas|Christian Keine|Satoko Okayam...
#
#                                        containerURI  \
# 36    https://data.mendeley.com/datasets/mh34bc6gty
# 38    https://data.mendeley.com/datasets/mh34bc6gty
# 107   https://data.mendeley.com/datasets/tghr5d9zgx
# 128   https://data.mendeley.com/datasets/4wfyg22srj
# ...                                             ...
# 1982  https://data.mendeley.com/datasets/2csdvyry9t
# 1994  https://data.mendeley.com/datasets/xfvykctgp6
# 1997  https://data.mendeley.com/datasets/fvtfjyvw7d
# 1999  https://data.mendeley.com/datasets/v88r5t5myz
#
#                                               dataTypes dateAvailable  \
# 36                SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# 38                SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# 107                                    DATASET|FILE_SET    2018-11-11
# 128                         OTHER|SOFTWARE_CODE|DATASET    2018-12-06
# ...                                                 ...           ...
# 1982                         SOFTWARE_CODE|DATASET|TEXT    2019-08-21
# 1994                     SOFTWARE_CODE|DATASET|FILE_SET    2019-04-04
# 1997                      TABULAR_DATA|DATASET|FILE_SET    2020-03-04
# 1999  SOFTWARE_CODE|IMAGE|VIDEO|TABULAR_DATA|DATASET...    2019-10-29
#
#                                             description  \
# 36    The dataset presented here is supporting the a...
# 38    The dataset presented here is supporting the a...
# 107   This data has three parts: \n\n1. C++ code for...
# 128   This is an example of the input files required...
# ...                                                 ...
# 1982  The data contain annual observations of ground...
# 1994  This data repository comprises the data and co...
# 1997  This dataset is shared by Dr. Jibo HE, founder...
# 1999  Contains data and software from the publicatio...
#
#                         doi  \
# 36    10.17632/mh34bc6gty.1
# 38    10.17632/mh34bc6gty.1
# 107   10.17632/tghr5d9zgx.2
# 128   10.17632/4wfyg22srj.1
# ...                     ...
# 1982  10.17632/2csdvyry9t.1
# 1994  10.17632/xfvykctgp6.1
# 1997  10.17632/fvtfjyvw7d.2
# 1999  10.17632/v88r5t5myz.4
#
#                                    externalSubjectAreas  \
# 36                        Molecular Dynamics|Biophysics
# 38                        Molecular Dynamics|Biophysics
# 107                                  Molecular Dynamics
# 128                                  Molecular Dynamics
# ...                                                 ...
# 1982  Hydrology|Agricultural Irrigation|Agricultural...
# 1994                    Marine Biology|Natural Sciences
# 1997        Big Data|University Student|Online Teaching
# 1999  Electron Microscopy|Light Microscopy|Presynapt...
#
#                                            institutions  \
# 36            Institut Pasteur|Universite de Strasbourg
# 38            Institut Pasteur|Universite de Strasbourg
# 107                  University of Texas at San Antonio
# 128                                                 NaN
# ...                                                 ...
# 1982  Colorado State University|University of Nebras...
# 1994                  Universita degli Studi di Bologna
# 1997              Tsinghua University|Peking University
# 1999    University of Iowa|Max Planck Florida Institute
#
#                                                keywords  \
# 36                        Molecular Dynamics|Biophysics
# 38                        Molecular Dynamics|Biophysics
# 107                                  Molecular Dynamics
# 128                                  Molecular Dynamics
# ...                                                 ...
# 1982  Hydrology|Agricultural Irrigation|Agricultural...
# 1994                    Marine Biology|Natural Sciences
# 1997        Big Data|University Student|Online Teaching
# 1999  Electron Microscopy|Light Microscopy|Presynapt...
#
#                                                  method publicationDate  \
# 36    Molecular Dynamics simulations where carried o...      2018-09-13
# 38    Molecular Dynamics simulations where carried o...      2018-09-13
# 107   1. tar zxvf  *.gz\n2. go to rasral/100-equil a...      2018-11-11
# 128    In order to perform the calculation, first yo...      2018-12-06
# ...                                                 ...             ...
# 1982  Steps to reproduce the results can be found at...      2019-08-21
# 1994  The html files contain the R codes used to mak...      2019-04-04
# 1997  Using web crawling techniques, 1.8 million ori...      2020-03-04
# 1999  All data are stored in CSV-files with periods ...      2019-10-29
#
#              source                                              title  \
# 36    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# 38    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# 107   MENDELEY_DATA  hSMD code, scripts, and coordinates for protei...
# 128   MENDELEY_DATA  MTP as a promising tool to study diffusion - r...
# ...             ...                                                ...
# 1982  MENDELEY_DATA  Annual well-level groundwater use records and ...
# 1994  MENDELEY_DATA  Influence of ambient temperature on the photos...
# 1997  MENDELEY_DATA  Big Data Set from RateMyProfessor.com for Prof...
# 1999  MENDELEY_DATA  Data/Software for "Presynaptic Mitochondria Vo...
#
#      type_cont  version
# 36     article      1.0
# 38     article      1.0
# 107    article      2.0
# 128    article      1.0
# ...        ...      ...
# 1982   article      1.0
# 1994   article      1.0
# 1997   article      2.0
# 1999   article      4.0
#
# [86 rows x 16 columns]

# %%
mt_data.loc[mt_data["method"].notnull()]
# Out:
#                                    accessRights  \
# 9    http://creativecommons.org/licenses/by/4.0
# 308  http://creativecommons.org/licenses/by/4.0
# 339  http://creativecommons.org/licenses/by/4.0
# 386  http://creativecommons.org/licenses/by/4.0
# ..                                          ...
# 419  http://creativecommons.org/licenses/by/4.0
# 421  http://creativecommons.org/licenses/by/4.0
# 423  http://creativecommons.org/licenses/by/4.0
# 433  http://creativecommons.org/licenses/by/4.0
#
#                                                authors  \
# 9         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# 308                                     Edoardo Paluan
# 339  YAO YI|Xu Jiang He|Andrew B Barron|Yi Bo Liu|Z...
# 386                                    Lisa Rose-Wiles
# ..                                                 ...
# 419       Maycon Franco|GILBERTO PEREZ|SILVIO POPADIUK
# 421                          Alexis Huf|Frank Siqueira
# 423                                     Danny S Guamán
# 433  charles-francois LATCHOUMANE|Lohitash Karumbai...
#
#                                       containerURI  \
# 9    https://data.mendeley.com/datasets/mh34bc6gty
# 308  https://data.mendeley.com/datasets/2ct5gfw6s3
# 339  https://data.mendeley.com/datasets/wzfmyz3rp8
# 386  https://data.mendeley.com/datasets/7fk4n7ych7
# ..                                             ...
# 419  https://data.mendeley.com/datasets/4x7xkj3d4p
# 421  https://data.mendeley.com/datasets/hcbcg23836
# 423  https://data.mendeley.com/datasets/zvp3986f5b
# 433  https://data.mendeley.com/datasets/743vvdtk7n
#
#                                              dataTypes dateAvailable  \
# 9                SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# 308  OTHER|SOFTWARE_CODE|GEO_DATA|IMAGE|TABULAR_DAT...    2016-12-06
# 339                               TABULAR_DATA|DATASET    2020-04-24
# 386                               TABULAR_DATA|DATASET    2018-05-24
# ..                                                 ...           ...
# 419                               TABULAR_DATA|DATASET    2019-01-15
# 421  OTHER|SOFTWARE_CODE|TABULAR_DATA|DATASET|DOCUM...    2019-01-04
# 423  OTHER|TABULAR_DATA|DATASET|DOCUMENT|TEXT|FILE_SET    2020-03-08
# 433                 SOFTWARE_CODE|TABULAR_DATA|DATASET    2020-03-16
#
#                                            description                    doi  \
# 9    The dataset presented here is supporting the a...  10.17632/mh34bc6gty.1
# 308  The aim of the task was to investigate the Dia...  10.17632/2ct5gfw6s3.1
# 339  Whether a female honey bee (Apis mellifera) de...  10.17632/wzfmyz3rp8.2
# 386  This is the raw data for our samples of refere...  10.17632/7fk4n7ych7.1
# ..                                                 ...                    ...
# 419  This accelerator is based on the bibliometric ...  10.17632/4x7xkj3d4p.1
# 421  This repository contains document data for a S...  10.17632/hcbcg23836.2
# 423  This repo contains the data used in a systemat...  10.17632/zvp3986f5b.1
# 433  Data set extracted from https://globalclinical...  10.17632/743vvdtk7n.1
#
#                                   externalSubjectAreas  \
# 9                        Molecular Dynamics|Biophysics
# 308  Molecules|Density Functional Theory (DFT)|Comp...
# 339           Inheritance|Epigenetics|Honey Bee|Insect
# 386          Library and Information Science|Chemistry
# ..                                                 ...
# 419                                      Bibliometrics
# 421  Software Engineering|Systematic Review|Web Ser...
# 423  Engineering|Privacy|Computer Science|Software ...
# 433                           Clinical Data Collection
#
#                                           institutions  \
# 9            Institut Pasteur|Universite de Strasbourg
# 308                              King's College London
# 339  Macquarie University Department of Biological ...
# 386                              Seton Hall University
# ..                                                 ...
# 419               Universidade Presbiteriana Mackenzie
# 421  Coordenacao de Aperfeicoamento de Pessoal de N...
# 423  Escuela Politecnica Nacional|Universidad Polit...
# 433                              University of Georgia
#
#                                               keywords  \
# 9                        Molecular Dynamics|Biophysics
# 308  Molecules|Density Functional Theory (DFT)|Comp...
# 339           Inheritance|Epigenetics|Honey Bee|Insect
# 386          Library and Information Science|Chemistry
# ..                                                 ...
# 419                                      Bibliometrics
# 421  Software Engineering|Systematic Review|Web Ser...
# 423  Engineering|Privacy|Computer Science|Software ...
# 433                           Clinical Data Collection
#
#                                                 method publicationDate  \
# 9    Molecular Dynamics simulations where carried o...      2018-09-13
# 308  The code essentially utilises the Klenmar-Byla...      2016-12-06
# 339  G1E were generation 1 queens reared from eggs ...      2020-04-24
# 386  The methodology is described in the associated...      2018-05-24
# ..                                                 ...             ...
# 419  The usage instructions can be accessed at this...      2019-01-15
# 421  To reproduce the automated stages of selection...      2019-01-04
# 423  Read the associated paper that contains the me...      2020-03-08
# 433  run analyze_ClinicalTrials.m having all xls. f...      2020-03-16
#
#             source                                              title  \
# 9    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# 308  MENDELEY_DATA  Density functional theory simulations of molec...
# 339  MENDELEY_DATA  Transgenerational accumulation of methylome ch...
# 386  MENDELEY_DATA                      Chemistry reference data 2018
# ..             ...                                                ...
# 419  MENDELEY_DATA                 Accelerator for bibliometric study
# 421  MENDELEY_DATA  Documents Data for "Composition of Heterogeneo...
# 423  MENDELEY_DATA  A Systematic Mapping Study on Software Quality...
# 433  MENDELEY_DATA  Neurostimulation and reach-to-grasp function r...
#
#     type_cont  version
# 9     article      1.0
# 308   article      1.0
# 339   article      2.0
# 386   article      1.0
# ..        ...      ...
# 419   article      1.0
# 421   article      2.0
# 423   article      1.0
# 433   article      1.0
#
# [13 rows x 16 columns]

# %%
md_data.loc[md_data["institutions"].notnull()]
# Out:
#                                     accessRights  \
# 3                                            NaN
# 21                                           NaN
# 36    http://creativecommons.org/licenses/by/4.0
# 38    http://creativecommons.org/licenses/by/4.0
# ...                                          ...
# 1990  http://creativecommons.org/licenses/by/4.0
# 1994  http://creativecommons.org/licenses/by/4.0
# 1997  http://creativecommons.org/licenses/by/4.0
# 1999  http://creativecommons.org/licenses/by/4.0
#
#                                                 authors  \
# 3                   Laranjeiro, Ricardo|Whitmore, David
# 21    Risso, Valeria A.|Martinez Rodriguez, Sergio|C...
# 36         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# 38         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# ...                                                 ...
# 1990  Ryuta Shioi|Fumika Karaki|Hiromasa Yoshioka|To...
# 1994                            Francesco Paolo Mancuso
# 1997                                            Jibo He
# 1999  Connon I. Thomas|Christian Keine|Satoko Okayam...
#
#                                        containerURI  \
# 3               https://doi.org/10.5061/dryad.r07bc
# 21              https://doi.org/10.5061/dryad.53629
# 36    https://data.mendeley.com/datasets/mh34bc6gty
# 38    https://data.mendeley.com/datasets/mh34bc6gty
# ...                                             ...
# 1990  https://data.mendeley.com/datasets/jr23ccpp46
# 1994  https://data.mendeley.com/datasets/xfvykctgp6
# 1997  https://data.mendeley.com/datasets/fvtfjyvw7d
# 1999  https://data.mendeley.com/datasets/v88r5t5myz
#
#                                               dataTypes dateAvailable  \
# 3                                  TABULAR_DATA|DATASET    2014-06-13
# 21                                     DATASET|FILE_SET    2017-07-20
# 36                SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# 38                SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# ...                                                 ...           ...
# 1990  SOFTWARE_CODE|IMAGE|TABULAR_DATA|DATASET|DOCUM...    2020-04-20
# 1994                     SOFTWARE_CODE|DATASET|FILE_SET    2019-04-04
# 1997                      TABULAR_DATA|DATASET|FILE_SET    2020-03-04
# 1999  SOFTWARE_CODE|IMAGE|VIDEO|TABULAR_DATA|DATASET...    2019-10-29
#
#                                             description  \
# 3     The circadian clock is known to regulate a wid...
# 21    Protein engineering studies often suggest the ...
# 36    The dataset presented here is supporting the a...
# 38    The dataset presented here is supporting the a...
# ...                                                 ...
# 1990  An example data set and accompanying R script ...
# 1994  This data repository comprises the data and co...
# 1997  This dataset is shared by Dr. Jibo HE, founder...
# 1999  Contains data and software from the publicatio...
#
#                         doi  \
# 3       10.5061/dryad.r07bc
# 21      10.5061/dryad.53629
# 36    10.17632/mh34bc6gty.1
# 38    10.17632/mh34bc6gty.1
# ...                     ...
# 1990  10.17632/jr23ccpp46.1
# 1994  10.17632/xfvykctgp6.1
# 1997  10.17632/fvtfjyvw7d.2
# 1999  10.17632/v88r5t5myz.4
#
#                                    externalSubjectAreas  \
# 3     photoreceptors|neuroD|retina|transcription fac...
# 21                                                  NaN
# 36                        Molecular Dynamics|Biophysics
# 38                        Molecular Dynamics|Biophysics
# ...                                                 ...
# 1990                           Screening|Image Analysis
# 1994                    Marine Biology|Natural Sciences
# 1997        Big Data|University Student|Online Teaching
# 1999  Electron Microscopy|Light Microscopy|Presynapt...
#
#                                            institutions  \
# 3     Centre for Cell and Molecular Dynamics, Depart...
# 21    Departamento de Quimica Fisica|Facultad de Cie...
# 36            Institut Pasteur|Universite de Strasbourg
# 38            Institut Pasteur|Universite de Strasbourg
# ...                                                 ...
# 1990  Tokyo Daigaku Teiryo Seimei Kagaku Kenkyujo|RI...
# 1994                  Universita degli Studi di Bologna
# 1997              Tsinghua University|Peking University
# 1999    University of Iowa|Max Planck Florida Institute
#
#                                                keywords  \
# 3                                           Danio rerio
# 21                                                  NaN
# 36                        Molecular Dynamics|Biophysics
# 38                        Molecular Dynamics|Biophysics
# ...                                                 ...
# 1990                           Screening|Image Analysis
# 1994                    Marine Biology|Natural Sciences
# 1997        Big Data|University Student|Online Teaching
# 1999  Electron Microscopy|Light Microscopy|Presynapt...
#
#                                                  method publicationDate  \
# 3                                                   NaN      2014-06-13
# 21                                                  NaN      2017-07-20
# 36    Molecular Dynamics simulations where carried o...      2018-09-13
# 38    Molecular Dynamics simulations where carried o...      2018-09-13
# ...                                                 ...             ...
# 1990                                                NaN      2020-04-20
# 1994  The html files contain the R codes used to mak...      2019-04-04
# 1997  Using web crawling techniques, 1.8 million ori...      2020-03-04
# 1999  All data are stored in CSV-files with periods ...      2019-10-29
#
#              source                                              title  \
# 3             DRYAD  Data from: Transcription factors involved in r...
# 21            DRYAD  Data from: De novo active sites for resurrecte...
# 36    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# 38    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# ...             ...                                                ...
# 1990  MENDELEY_DATA  Supplementary datasets and R scripts for: Imag...
# 1994  MENDELEY_DATA  Influence of ambient temperature on the photos...
# 1997  MENDELEY_DATA  Big Data Set from RateMyProfessor.com for Prof...
# 1999  MENDELEY_DATA  Data/Software for "Presynaptic Mitochondria Vo...
#
#      type_cont  version
# 3          NaN      NaN
# 21         NaN      NaN
# 36     article      1.0
# 38     article      1.0
# ...        ...      ...
# 1990   article      1.0
# 1994   article      1.0
# 1997   article      2.0
# 1999   article      4.0
#
# [308 rows x 16 columns]

# %%
mt_data.loc[mt_data["institutions"].notnull()]
# Out:
#                                    accessRights  \
# 8    http://creativecommons.org/licenses/by/4.0
# 9    http://creativecommons.org/licenses/by/4.0
# 14            info:eu-repo/semantics/openAccess
# 16   http://creativecommons.org/licenses/by/4.0
# ..                                          ...
# 433  http://creativecommons.org/licenses/by/4.0
# 434  http://creativecommons.org/licenses/by/4.0
# 436  http://creativecommons.org/licenses/by/4.0
# 437  http://creativecommons.org/licenses/by/4.0
#
#                                                authors  \
# 8            Yevgen Yurenko|Martin Lepšík|Juraj Dobiaš
# 9         Adrien Cerdan|Nicolas  Martin|Marco Cecchini
# 14               Stachura, Sławomir|Kneller, Gerald R.
# 16                               Alessandro Nascimento
# ..                                                 ...
# 433  charles-francois LATCHOUMANE|Lohitash Karumbai...
# 434                       Charles-Francois Latchoumane
# 436                           Agung Purnomo|Nur Asitah
# 437                      Agung Purnomo|Andre Septianto
#
#                                       containerURI  \
# 8    https://data.mendeley.com/datasets/vtxgt2y9rc
# 9    https://data.mendeley.com/datasets/mh34bc6gty
# 14                 https://zenodo.org/record/61743
# 16   https://data.mendeley.com/datasets/ptxn54nc8m
# ..                                             ...
# 433  https://data.mendeley.com/datasets/743vvdtk7n
# 434  https://data.mendeley.com/datasets/77pxrcssj3
# 436  https://data.mendeley.com/datasets/dsdnv2s7t3
# 437  https://data.mendeley.com/datasets/c77sxxms9f
#
#                                  dataTypes dateAvailable  \
# 8       OTHER|SEQUENCING_DATA|DATASET|TEXT    2019-05-16
# 9    SOFTWARE_CODE|SEQUENCING_DATA|DATASET    2018-09-13
# 14                           OTHER|DATASET    2016-09-12
# 16                        DATASET|FILE_SET    2018-12-07
# ..                                     ...           ...
# 433     SOFTWARE_CODE|TABULAR_DATA|DATASET    2020-03-16
# 434     SOFTWARE_CODE|TABULAR_DATA|DATASET    2020-04-15
# 436                   TABULAR_DATA|DATASET    2020-03-28
# 437                   TABULAR_DATA|DATASET    2020-04-08
#
#                                            description                    doi  \
# 8    The dataset contains molecular dynamics trajec...  10.17632/vtxgt2y9rc.1
# 9    The dataset presented here is supporting the a...  10.17632/mh34bc6gty.1
# 14   This file contains the center-of-mass coordina...   10.5281/zenodo.61743
# 16   This dataset contains the MD trajectories of c...  10.17632/ptxn54nc8m.1
# ..                                                 ...                    ...
# 433  Data set extracted from https://globalclinical...  10.17632/743vvdtk7n.1
# 434  Clinical trials posted and filtered for brain ...  10.17632/77pxrcssj3.1
# 436  The knowledge management reseach dataset with ...  10.17632/dsdnv2s7t3.1
# 437  The brand management reseach & publication dat...  10.17632/c77sxxms9f.2
#
#                                   externalSubjectAreas  \
# 8    Molecular Dynamics|DNA|Ligand Binding|Molecula...
# 9                        Molecular Dynamics|Biophysics
# 14        POPC|ActivePapers|MARTINI|molecular dynamics
# 16   Biotechnology|Molecular Mechanics with Molecul...
# ..                                                 ...
# 433                           Clinical Data Collection
# 434                             Clinical Trial Results
# 436           Knowledge Management|Management|Business
# 437     Brand Management|Management|Business|Marketing
#
#                                           institutions  \
# 8    Ustav organicke chemie a biochemie Akademie ve...
# 9            Institut Pasteur|Universite de Strasbourg
# 14   Centre de Biophysique Moléculaire|CNRS|Synchro...
# 16   Universidade de Sao Paulo Instituto de Fisica ...
# ..                                                 ...
# 433                              University of Georgia
# 434                              University of Georgia
# 436                          Bina Nusantara University
# 437    Bina Nusantara University|Universitas Airlangga
#
#                                               keywords  \
# 8    Molecular Dynamics|DNA|Ligand Binding|Molecula...
# 9                        Molecular Dynamics|Biophysics
# 14        POPC|ActivePapers|MARTINI|molecular dynamics
# 16   Biotechnology|Molecular Mechanics with Molecul...
# ..                                                 ...
# 433                           Clinical Data Collection
# 434                             Clinical Trial Results
# 436           Knowledge Management|Management|Business
# 437     Brand Management|Management|Business|Marketing
#
#                                                 method publicationDate  \
# 8                                                  NaN      2019-05-16
# 9    Molecular Dynamics simulations where carried o...      2018-09-13
# 14                                                 NaN      2016-09-07
# 16                                                 NaN      2018-12-07
# ..                                                 ...             ...
# 433  run analyze_ClinicalTrials.m having all xls. f...      2020-03-16
# 434                                                NaN      2020-04-15
# 436                                                NaN      2020-03-28
# 437                                                NaN      2020-04-08
#
#             source                                              title  \
# 8    MENDELEY_DATA  Structures, molecular dynamics trajectories an...
# 9    MENDELEY_DATA  An ion permeable state of the Glycine Receptor...
# 14          ZENODO  Lipid center-of-mass trajectory: long-time dyn...
# 16   MENDELEY_DATA  Structure and Dynamics of Trichoderma harzianu...
# ..             ...                                                ...
# 433  MENDELEY_DATA  Neurostimulation and reach-to-grasp function r...
# 434  MENDELEY_DATA        Brain Injury Neuromodulation Reach-to-Grasp
# 436  MENDELEY_DATA  Knowledge Management Research in Indonesia Dat...
# 437  MENDELEY_DATA         Brand Management Research Data (1968-2019)
#
#     type_cont  version
# 8     article      1.0
# 9     article      1.0
# 14    article      NaN
# 16    article      1.0
# ..        ...      ...
# 433   article      1.0
# 434   article      1.0
# 436   article      1.0
# 437   article      2.0
#
# [86 rows x 16 columns]

# %% [markdown]
# Let's reset the index to reflect the new data frame:

# %%
md_clean = md_data.copy()
md_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2002 entries, 0 to 2001
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accessRights          1546 non-null   object
#  1   authors               2001 non-null   object
#  2   containerURI          2002 non-null   object
#  3   dataTypes             2002 non-null   object
#  4   dateAvailable         1245 non-null   object
#  5   description           2002 non-null   object
#  6   doi                   2002 non-null   object
#  7   externalSubjectAreas  1786 non-null   object
#  8   institutions          308 non-null    object
#  9   keywords              967 non-null    object
#  10  method                86 non-null     object
#  11  publicationDate       2000 non-null   object
#  12  source                2002 non-null   object
#  13  title                 2002 non-null   object
#  14  type_cont             982 non-null    object
#  15  version               626 non-null    float64
# dtypes: float64(1), object(15)
# memory usage: 250.4+ KB

# %%
first_term
# Out:
# ['orf1ab',
#  'orf3a',
#  'orf6',
#  'orf7a',
#  'orf8',
#  'orf10',
#  'nsp1',
#  'nsp2',
#  'nps3',
#  'nps4',
#  'nsp5',
#  'nsp6',
#  'nsp7',
#  'nsp8',
#  'nsp9',
#  'nsp10',
#  'rdrp',
#  '3cl-pro',
#  'host translation inhibitor nsp1',
#  'papain-like proteinase',
#  '3c-like proteinase',
#  'uridylate-specific endoribonuclease',
#  "2'-o-methyltransferase",
#  'protein 3a',
#  'protein 6',
#  'protein 7a',
#  'protein 8',
#  'sars-cov-2',
#  'sars-cov2',
#  'covid19',
#  'covid-19',
#  'sars',
#  'coronavirus',
#  'ncov2019',
#  'ncov-2019',
#  'ncov2019',
#  'ncov-2019',
#  'covid2019',
#  'ncov']

# %% [markdown]
# By looking at excerpt, what could be searched is first to look for `first_term` keywords in all columns but `Authors` and `Type of possible) format` and then look for `second_term` keywords in `Keywords` and `Description` columns to focus in on Molecular dynamics data.

# %% [markdown]
# ## Finding all rows with keywords in them in `Title` and `Description` columns
# The purpose of initialising pd.Series name `found` is to hold a boolen index rows with matches (if a certain keyword is found in the particular entry).

# %%
falses_md = np.zeros(len(md_data["title"]), dtype=bool) # https://stackoverflow.com/a/21174962
falses_mt = np.zeros(len(mt_data["title"]), dtype=bool)
found_md = pd.Series(data = falses_md,
                   dtype = bool)
found_mt = pd.Series(data = falses_mt,
                   dtype = bool)
#found2 = pd.Series(data = falses,
#                   dtype = bool)

# %% [markdown]
# ### Find all indexes with a match

# %% [markdown]
# #### Obtain column names of interest to loop through

# %%
num_elem_md = len(md_data.columns.values.tolist())
num_elem_mt = len(mt_data.columns.values.tolist())
cols_md = md_data.columns.values.tolist()
cols_mt = mt_data.columns.values.tolist()
print(cols_md)
# Out:
# ['accessRights', 'authors', 'containerURI', 'dataTypes', 'dateAvailable', 'description', 'doi', 'externalSubjectAreas', 'institutions', 'keywords', 'method', 'publicationDate', 'source', 'title', 'type_cont', 'version']

# %% [markdown]
# Let's remove the last element from the list of column names ("version" column) because its data type is float and it can't be searched in the next step with string search.

# %%
cols_md.pop(num_elem_md-1)
cols_mt.pop(num_elem_mt-1)
print(cols_mt)
# Out:
# ['accessRights', 'authors', 'containerURI', 'dataTypes', 'dateAvailable', 'description', 'doi', 'externalSubjectAreas', 'institutions', 'keywords', 'method', 'publicationDate', 'source', 'title', 'type_cont']

# %% [markdown]
# ### Find matches in the "Molecular dynamics" keyword search

# %%
for col in cols_md:
    for word in first_term:
        # Find out if the current search term can be found in the column
        cur_match = md_data[col].str.lower().str.contains(word) # https://stackoverflow.com/a/15333283
        # Join the found matches to one Series
        found_md = found_md | cur_match

# %% [markdown]
# Let's check how many rows got some hits with these keywords

# %%
found_md.value_counts()
# Out:
# False    1937
# True       65
# dtype: int64

# %% [markdown]
# Let's check out some of the matches:

# %%
md_data[found_md].head()
# Out:
#                                    accessRights  \
# 133  http://creativecommons.org/licenses/by/4.0
# 168           info:eu-repo/semantics/openAccess
# 184           info:eu-repo/semantics/openAccess
# 191  http://creativecommons.org/licenses/by/4.0
# 199                                   CC BY 4.0
#
#                                                authors  \
# 133  Teruhisa S. KOMATSU|Yohei Koyama|Noriaki OKIMO...
# 168  Durdagi, Serdar|Aksoydan, Busecan|Dogan, Berna...
# 184  Durdagi, Serdar|Aksoydan, Busecan|Dogan, Berna...
# 191  Ryunosuke Yoshino|Nobuaki Yasuo|Masakazu Sekijima
# 199  Cespugli, Marco|Durmaz, Vedat|Steinkellner, Ge...
#
#                                           containerURI  \
# 133      https://data.mendeley.com/datasets/vpps4vhryg
# 168                  https://zenodo.org/record/3756976
# 184                  https://zenodo.org/record/3751321
# 191      https://data.mendeley.com/datasets/5jfsx6j75g
# 199  https://figshare.com/articles/Molecular_dynami...
#
#                                  dataTypes dateAvailable  \
# 133  OTHER|IMAGE|TABULAR_DATA|DATASET|TEXT    2020-04-27
# 168                                DATASET    2020-04-19
# 184                                DATASET    2020-04-15
# 191                       DATASET|FILE_SET    2020-04-21
# 199                                DATASET           NaN
#
#                                            description  \
# 133  Raw trajectory data (GROMACS format) of 10 mic...
# 168  Data includes all of the trajectories (1000) o...
# 184  Data includes all of the trajectories (2000) o...
# 191  MD simulations were performed using Desmond on...
# 199  Molecular dynamics simulations (500 ps MD at 3...
#
#                                  doi  \
# 133            10.17632/vpps4vhryg.2
# 168           10.5281/zenodo.3756976
# 184           10.5281/zenodo.3751321
# 191            10.17632/5jfsx6j75g.2
# 199  10.6084/m9.figshare.11788794.v1
#
#                                   externalSubjectAreas institutions  \
# 133                      Virus|Drug|Molecular Dynamics          NaN
# 168  SARS-CoV2 Main Protease, holo form, PDB 6LU7, ...          NaN
# 184  SARS-CoV2 Main Protease, lopinavir, molecular ...          NaN
# 191  Drug|Coronavirus Disease 2019|Molecular Dynami...          NaN
# 199                60102 Bioinformatics|60506 Virology          NaN
#
#                                               keywords method publicationDate  \
# 133                      Virus|Drug|Molecular Dynamics    NaN      2020-04-27
# 168  SARS-CoV2 Main Protease, holo form, PDB 6LU7, ...    NaN      2020-04-18
# 184  SARS-CoV2 Main Protease, lopinavir, molecular ...    NaN      2020-04-14
# 191  Drug|Coronavirus Disease 2019|Molecular Dynami...    NaN      2020-04-21
# 199                                                NaN    NaN      2020-01-01
#
#             source                                              title  \
# 133  MENDELEY_DATA  COVID-19 related trajectory data of 10 microse...
# 168         ZENODO  All Atom Molecular Dynamics Simulations of inh...
# 184         ZENODO  All Atom Molecular Dynamics Simulations of Lop...
# 191  MENDELEY_DATA  Trajectory data of molecular dynamics simulati...
# 199   figshare.ars  Molecular dynamics simulations of coronavirus ...
#
#     type_cont  version
# 133   article      2.0
# 168   article      NaN
# 184   article      NaN
# 191   article      2.0
# 199       NaN      NaN

# %% [markdown]
# ### Find matches in the "Molecular trajectories" keyword search

# %%
for col in cols_mt:
    for word in first_term:
        # Find out if the current search term can be found in the column
        cur_match = mt_data[col].str.lower().str.contains(word) # https://stackoverflow.com/a/15333283
        # Join the found matches to one Series
        found_mt = found_mt | cur_match

# %% [markdown]
# Let's check how many rows got some hits with these keywords

# %%
found_mt.value_counts()
# Out:
# False    417
# True      21
# dtype: int64

# %% [markdown]
# Let's check out some of the matches:

# %%
mt_data[found_mt].head()
# Out:
#                                    accessRights  \
# 105  http://creativecommons.org/licenses/by/4.0
# 139  http://creativecommons.org/licenses/by/4.0
# 153           info:eu-repo/semantics/openAccess
# 156           info:eu-repo/semantics/openAccess
# 179           info:eu-repo/semantics/openAccess
#
#                                                authors  \
# 105  Teruhisa S. KOMATSU|Yohei Koyama|Noriaki OKIMO...
# 139  Ryunosuke Yoshino|Nobuaki Yasuo|Masakazu Sekijima
# 153  Durdagi, Serdar|Aksoydan, Busecan|Dogan, Berna...
# 156  Durdagi, Serdar|Aksoydan, Busecan|Dogan, Berna...
# 179                            Průša Jiří|Cifra Michal
#
#                                       containerURI  \
# 105  https://data.mendeley.com/datasets/vpps4vhryg
# 139  https://data.mendeley.com/datasets/5jfsx6j75g
# 153              https://zenodo.org/record/3756976
# 156              https://zenodo.org/record/3746892
# 179              https://zenodo.org/record/3352030
#
#                                  dataTypes dateAvailable  \
# 105  OTHER|IMAGE|TABULAR_DATA|DATASET|TEXT    2020-04-27
# 139                       DATASET|FILE_SET    2020-04-21
# 153                                DATASET    2020-04-19
# 156                                DATASET    2020-04-09
# 179                       DATASET|FILE_SET    2019-08-06
#
#                                            description  \
# 105  Raw trajectory data (GROMACS format) of 10 mic...
# 139  MD simulations were performed using Desmond on...
# 153  Data includes all of the trajectories (1000) o...
# 156  Data includes all of the trajectories (2000) o...
# 179  We present molecular dynamics (MD) trajectorie...
#
#                         doi  \
# 105   10.17632/vpps4vhryg.2
# 139   10.17632/5jfsx6j75g.2
# 153  10.5281/zenodo.3756976
# 156  10.5281/zenodo.3746892
# 179  10.5281/zenodo.3352030
#
#                                   externalSubjectAreas institutions  \
# 105                      Virus|Drug|Molecular Dynamics          NaN
# 139  Drug|Coronavirus Disease 2019|Molecular Dynami...          NaN
# 153  SARS-CoV2 Main Protease, holo form, PDB 6LU7, ...          NaN
# 156  SARS-CoV2 Main Protease, ritonavir, molecular ...          NaN
# 179  Dielectric spectroscopy|Amino acid|Molecular d...          NaN
#
#                                               keywords method publicationDate  \
# 105                      Virus|Drug|Molecular Dynamics    NaN      2020-04-27
# 139  Drug|Coronavirus Disease 2019|Molecular Dynami...    NaN      2020-04-21
# 153  SARS-CoV2 Main Protease, holo form, PDB 6LU7, ...    NaN      2020-04-18
# 156  SARS-CoV2 Main Protease, ritonavir, molecular ...    NaN      2020-04-09
# 179  Dielectric spectroscopy|Amino acid|Molecular d...    NaN      2019-07-31
#
#             source                                              title  \
# 105  MENDELEY_DATA  COVID-19 related trajectory data of 10 microse...
# 139  MENDELEY_DATA  Trajectory data of molecular dynamics simulati...
# 153         ZENODO  All Atom Molecular Dynamics Simulations of inh...
# 156         ZENODO  All Atom Molecular Dynamics Simulations of Rit...
# 179         ZENODO                            Dataset A1606 and A1905
#
#     type_cont  version
# 105   article      2.0
# 139   article      2.0
# 153   article      NaN
# 156   article      NaN
# 179   article      NaN

# %% [markdown]
# ## Output the filtered data sets as tsv files

# %%
results = "02_processed/"
md_copy = md_data[found_md].copy()
# Set row names to start from 0 again instead of the indexing before filtering
md_copy.reset_index(drop = True).to_csv(path_or_buf = results + "filtered_molecular_dynamics.tsv",
                         sep = "\t"
                        )

# %%
mt_copy = mt_data[found_mt].copy()

mt_copy.reset_index(drop = True).to_csv(path_or_buf = results + "filtered_molecular_trajectories.tsv",
                         sep = "\t"
                        )
